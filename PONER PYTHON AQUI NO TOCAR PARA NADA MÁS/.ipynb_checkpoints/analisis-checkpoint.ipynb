# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
db = pd.read_csv("STI PRUEBA.csv")
db = db.rename(columns={'Tarea 1': 'Tarea_1'})
db = db.rename(columns={'Tarea 2': 'Tarea_2'})
db = db.rename(columns={'Tarea 3': 'Tarea_3'})
print(db)
# Out:
#     P1  P2  P3  P4  P5  P6  Tarea_1  Tarea_2  Tarea_3
# 0    9  10   5  10  10   7       60       66       56
# 1    7   4   9  10   5  10       21       10       20
# 2   10  10  10  10   8  10       79       20       40
# 3   10   8  10   8   9   7       68       50       50
# 4   10  10  10  10  10  10       73       75       40
# 5    8   8  10  10  10  10       92       52       60
# 6    8   5   9   8  10   5       45       16       25
# 7   10  10  10  10  10  10       90       61       30
# 8    9   9   9  10   8   9       68       49       65
# 9   10   7  10  10  10  10       10       40       24
# 10   8   8   9  10  10   9      136       48      132
# 11   8   5   6   8   5   9       50       15       20
# 12   9   8  10  10  10   9       54       61       28

# %%
print(db.P1)
# Out:
# 0      9
# 1      7
# 2     10
# 3     10
# 4     10
# 5      8
# 6      8
# 7     10
# 8      9
# 9     10
# 10     8
# 11     8
# 12     9
# Name: P1, dtype: int64

# %%
fig_hist_tarea1, ax_hist_tarea1 = plt.subplots()
ax_hist_tarea1.boxplot(db.Tarea_1,)
fig_hist_tarea2, ax_hist_tarea2 = plt.subplots()
ax_hist_tarea2.boxplot(db.Tarea_2)
fig_hist_tarea3, ax_hist_tarea3 = plt.subplots()
ax_hist_tarea3.boxplot(db.Tarea_3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13069020650>,
#   <matplotlib.lines.Line2D at 0x13069021850>],
#  'caps': [<matplotlib.lines.Line2D at 0x130690234d0>,
#   <matplotlib.lines.Line2D at 0x13068fdc190>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13068fd84d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x13068fde7d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13068fdc5d0>],
#  'means': []}

# %%
promedio_P1 = np.mean(db.P1)
promedio_P2 = np.mean(db.P2)
promedio_P3 = np.mean(db.P3)
promedio_P4 = np.mean(db.P4)
promedio_P5 = np.mean(db.P5)
promedio_P6 = np.mean(db.P6)

# %%
ypromedios= [promedio_P1,promedio_P2,promedio_P3,promedio_P4,promedio_P5,promedio_P6]
xpromedios= ["Función 1", "Función 2", "Función 3","Función 4","Función 5","Función 6"]
fig_promedios,ax_promedios = plt.subplots()
ax_promedios.bar(x=xpromedios, height=ypromedios)
# Out:
# <BarContainer object of 6 artists>

# %%
fig_box_P1, ax_box_P1 = plt.subplots()
ax_box_P1.boxplot(db.P1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x130691f88d0>,
#   <matplotlib.lines.Line2D at 0x130691f9250>],
#  'caps': [<matplotlib.lines.Line2D at 0x130691f9b90>,
#   <matplotlib.lines.Line2D at 0x130691fa410>],
#  'boxes': [<matplotlib.lines.Line2D at 0x130691a98d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x130691fad90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13069139f90>],
#  'means': []}

# %%
fig_box_P2, ax_box_P2 = plt.subplots()
ax_box_P2.boxplot(db.P2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13069255f50>,
#   <matplotlib.lines.Line2D at 0x13069256950>],
#  'caps': [<matplotlib.lines.Line2D at 0x130692571d0>,
#   <matplotlib.lines.Line2D at 0x13069257a90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x130692557d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x130692683d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x130691d8150>],
#  'means': []}

# %%
fig_box_P3, ax_box_P3 = plt.subplots()
ax_box_P3.boxplot(db.P3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x130692bae50>,
#   <matplotlib.lines.Line2D at 0x130692bb990>],
#  'caps': [<matplotlib.lines.Line2D at 0x130692ad710>,
#   <matplotlib.lines.Line2D at 0x130692ccb90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x130692bae90>],
#  'medians': [<matplotlib.lines.Line2D at 0x130692cd3d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x130692cd710>],
#  'means': []}

# %%
fig_box_P4, ax_box_P4 = plt.subplots()
ax_box_P4.boxplot(db.P4)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1306932ab10>,
#   <matplotlib.lines.Line2D at 0x1306932b490>],
#  'caps': [<matplotlib.lines.Line2D at 0x1306932be50>,
#   <matplotlib.lines.Line2D at 0x1306931ad10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1306932a250>],
#  'medians': [<matplotlib.lines.Line2D at 0x13069334c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13069335490>],
#  'means': []}

# %%
fig_box_P5, ax_box_P5 = plt.subplots()
ax_box_P5.boxplot(db.P5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13069393a50>,
#   <matplotlib.lines.Line2D at 0x1306939c390>],
#  'caps': [<matplotlib.lines.Line2D at 0x1306939cc10>,
#   <matplotlib.lines.Line2D at 0x1306939d3d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13069393190>],
#  'medians': [<matplotlib.lines.Line2D at 0x1306939dc10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13069208890>],
#  'means': []}

# %%
fig_box_P6, ax_box_P6 = plt.subplots()
ax_box_P6.boxplot(db.P6)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13069461dd0>,
#   <matplotlib.lines.Line2D at 0x13069462ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x130694634d0>,
#   <matplotlib.lines.Line2D at 0x13069463fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x130694614d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x130694709d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13069471410>],
#  'means': []}

# %%
db = db.rename(columns={'Tarea 1': 'Tarea_1',
                        'Tarea 2': 'Tarea_2',
                        'Tarea 3': 'Tarea_3'})

# %%
datos = db[['P1', 'P2', 'P3', 'P4', 'P5', 'P6']]

# %%
datos = datos.values

# %%
plt.imshow(datos, cmap='viridis', aspect='auto')
plt.xlabel('Funcionalidades')
plt.ylabel('Personas')
plt.colorbar(label='Valores')
plt.show()

# %%
datos2 = db[['Tarea_1', 'Tarea_2', 'Tarea_3']]

# %%
datos2 = datos2.values

# %%
plt.imshow(datos2, cmap='viridis', aspect='auto')
plt.ylabel('Personas')
plt.colorbar(label='Segundos')
plt.show()
