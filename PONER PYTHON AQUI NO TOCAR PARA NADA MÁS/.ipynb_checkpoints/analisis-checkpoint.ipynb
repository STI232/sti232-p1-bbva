# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
db = pd.read_csv("STI PRUEBA.csv")
db = db.rename(columns={'Tarea 1': 'Tarea_1'})
db = db.rename(columns={'Tarea 2': 'Tarea_2'})
db = db.rename(columns={'Tarea 3': 'Tarea_3'})
print(db)
# Out:
#     P1  P2  P3  P4  P5  P6  Tarea_1  Tarea_2  Tarea_3
# 0    9  10   5  10  10   7       60       66       56
# 1    7   4   9  10   5  10       21       10       20
# 2   10  10  10  10   8  10       79       20       40
# 3   10   8  10   8   9   7       68       50       50
# 4   10  10  10  10  10  10       73       75       40
# 5    8   8  10  10  10  10       92       52       60
# 6    8   5   9   8  10   5       45       16       25
# 7   10  10  10  10  10  10       90       61       30
# 8    9   9   9  10   8   9       68       49       65
# 9   10   7  10  10  10  10       10       40       24
# 10   8   8   9  10  10   9      136       48      132
# 11   8   5   6   8   5   9       50       15       20
# 12   9   8  10  10  10   9       54       61       28

# %%
print(db.P1)
# Out:
# 0      9
# 1      7
# 2     10
# 3     10
# 4     10
# 5      8
# 6      8
# 7     10
# 8      9
# 9     10
# 10     8
# 11     8
# 12     9
# Name: P1, dtype: int64

# %%
fig_hist_tarea1, ax_hist_tarea1 = plt.subplots()
ax_hist_tarea1.boxplot(db.Tarea_1,)
fig_hist_tarea2, ax_hist_tarea2 = plt.subplots()
ax_hist_tarea2.boxplot(db.Tarea_2)
fig_hist_tarea3, ax_hist_tarea3 = plt.subplots()
ax_hist_tarea3.boxplot(db.Tarea_3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1305ea6a850>,
#   <matplotlib.lines.Line2D at 0x1305ea6b490>],
#  'caps': [<matplotlib.lines.Line2D at 0x1305ea6be10>,
#   <matplotlib.lines.Line2D at 0x1305ea74950>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1305ea69cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1305ea752d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1305ea45c50>],
#  'means': []}

# %%
promedio_P1 = np.mean(db.P1)
promedio_P2 = np.mean(db.P2)
promedio_P3 = np.mean(db.P3)
promedio_P4 = np.mean(db.P4)
promedio_P5 = np.mean(db.P5)
promedio_P6 = np.mean(db.P6)

# %%
ypromedios= [promedio_P1,promedio_P2,promedio_P3,promedio_P4,promedio_P5,promedio_P6]
xpromedios= ["Función 1", "Función 2", "Función 3","Función 4","Función 5","Función 6"]
fig_promedios,ax_promedios = plt.subplots()
ax_promedios.bar(x=xpromedios, height=ypromedios)
# Out:
# <BarContainer object of 6 artists>

# %%
fig_box_P1, ax_box_P1 = plt.subplots()
ax_box_P1.boxplot(db.P1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1305e8e09d0>,
#   <matplotlib.lines.Line2D at 0x1305e8e13d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1305e8e1cd0>,
#   <matplotlib.lines.Line2D at 0x1305e8e24d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1305e8e0150>],
#  'medians': [<matplotlib.lines.Line2D at 0x1305e8e2d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1305e8e34d0>],
#  'means': []}

# %%
fig_box_P2, ax_box_P2 = plt.subplots()
ax_box_P2.boxplot(db.P2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1305e93e590>,
#   <matplotlib.lines.Line2D at 0x1305e93f250>],
#  'caps': [<matplotlib.lines.Line2D at 0x1305e93fc50>,
#   <matplotlib.lines.Line2D at 0x1305e70c710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1305e93da90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1305e70d250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1305e84dc10>],
#  'means': []}

# %%
fig_box_P3, ax_box_P3 = plt.subplots()
ax_box_P3.boxplot(db.P3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1305e763210>,
#   <matplotlib.lines.Line2D at 0x1305e74a850>],
#  'caps': [<matplotlib.lines.Line2D at 0x1305e76c910>,
#   <matplotlib.lines.Line2D at 0x1305e76d310>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1305e74fc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1305e76dc50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1305e76e690>],
#  'means': []}

# %%
fig_box_P4, ax_box_P4 = plt.subplots()
ax_box_P4.boxplot(db.P4)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1305e7cd310>,
#   <matplotlib.lines.Line2D at 0x1305e7cdd10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1305e7ce810>,
#   <matplotlib.lines.Line2D at 0x1305e7cf290>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1305e7cc790>],
#  'medians': [<matplotlib.lines.Line2D at 0x1305e7cfdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1305e90cf50>],
#  'means': []}

# %%
fig_box_P5, ax_box_P5 = plt.subplots()
ax_box_P5.boxplot(db.P5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1305ec05a90>,
#   <matplotlib.lines.Line2D at 0x1305ec06690>],
#  'caps': [<matplotlib.lines.Line2D at 0x1305ec07190>,
#   <matplotlib.lines.Line2D at 0x1305ec07b10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1305ec04f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1305ec0c5d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1305e285950>],
#  'means': []}

# %%
fig_box_P6, ax_box_P6 = plt.subplots()
ax_box_P6.boxplot(db.P6)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1305ec64bd0>,
#   <matplotlib.lines.Line2D at 0x1305ec657d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1305ec662d0>,
#   <matplotlib.lines.Line2D at 0x1305ec66d10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1305ec64190>],
#  'medians': [<matplotlib.lines.Line2D at 0x1305ec67850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1305ec22ad0>],
#  'means': []}
