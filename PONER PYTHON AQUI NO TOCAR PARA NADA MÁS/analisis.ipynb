# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
db = pd.read_csv("STI PRUEBA.csv")
db = db.rename(columns={'Tarea 1': 'Tarea_1'})
db = db.rename(columns={'Tarea 2': 'Tarea_2'})
db = db.rename(columns={'Tarea 3': 'Tarea_3'})
print(db)
# Out:
#    P1  P2  P3  P4  P5  P6  Tarea_1  Tarea_2  Tarea_3
# 0   9  10   5  10  10   7       60       66       56
# 1   7   4   9  10   5  10       21       10       20
# 2  10  10  10  10   8  10       79       20       40
# 3  10   8  10   8   9   7       68       50       50
# 4  10  10  10  10  10  10       73       75       40

# %%
print(db.P1)
# Out:
# 0     9
# 1     7
# 2    10
# 3    10
# 4    10
# Name: P1, dtype: int64

# %%
fig_hist_tarea1, ax_hist_tarea1 = plt.subplots()
ax_hist_tarea1.boxplot(db.Tarea_1,)
fig_hist_tarea2, ax_hist_tarea2 = plt.subplots()
ax_hist_tarea2.boxplot(db.Tarea_2)
fig_hist_tarea3, ax_hist_tarea3 = plt.subplots()
ax_hist_tarea3.boxplot(db.Tarea_3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2592a18d150>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2592a18e890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2592a18c510>],
#  'medians': [<matplotlib.lines.Line2D at 0x2592a18fed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x259299ea710>],
#  'means': []}

# %%
promedio_P1 = np.mean(db.P1)
promedio_P2 = np.mean(db.P2)
promedio_P3 = np.mean(db.P3)
promedio_P4 = np.mean(db.P4)
promedio_P5 = np.mean(db.P5)
promedio_P6 = np.mean(db.P6)

# %%
ypromedios= [promedio_P1,promedio_P2,promedio_P3,promedio_P4,promedio_P5,promedio_P6]
xpromedios= ["Función 1", "Función 2", "Función 3","Función 4","Función 5","Función 6"]
fig_promedios,ax_promedios = plt.subplots()
ax_promedios.bar(x=xpromedios, height=ypromedios)
# Out:
# <BarContainer object of 6 artists>

# %%
fig_box_P1, ax_box_P1 = plt.subplots()
ax_box_P1.boxplot(db.P1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2592977fd50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x259297c2e10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25929bc0a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x259298ea890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x259298e8890>],
#  'means': []}

# %%
fig_box_P2, ax_box_P2 = plt.subplots()
ax_box_P2.boxplot(db.P2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25929859890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x259298c2210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25929b88850>],
#  'medians': [<matplotlib.lines.Line2D at 0x259298b90d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x259298b8690>],
#  'means': []}

# %%
fig_box_P3, ax_box_P3 = plt.subplots()
ax_box_P3.boxplot(db.P3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x259264c5990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2592914b090>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x259266541d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x259295dde10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25929ae7cd0>],
#  'means': []}

# %%
fig_box_P4, ax_box_P4 = plt.subplots()
ax_box_P4.boxplot(db.P4)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25929c42610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2592633ae10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x259267fa650>],
#  'medians': [<matplotlib.lines.Line2D at 0x25929d81310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25929d81e10>],
#  'means': []}

# %%
fig_box_P5, ax_box_P5 = plt.subplots()
ax_box_P5.boxplot(db.P5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25929c8aa10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25929e14150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25929c69ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x25929e15750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2592635a850>],
#  'means': []}

# %%
fig_box_P6, ax_box_P6 = plt.subplots()
ax_box_P6.boxplot(db.P6)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25929ede310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25929edfb90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25929e94ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x25929eed250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25929e45c90>],
#  'means': []}
